# %%
import torch
from PIL import Image
import torch
import torch.nn as nn
import torch.utils.checkpoint as checkpoint
from timm.models.layers import DropPath, to_2tuple, trunc_normal_
from torchvision.models.resnet import resnet18
from torchvision.models import resnet101
from efficientnet_pytorch import EfficientNet
from torchvision import datasets, transforms
from data.fetal_loader import Fetal_frame
from models.effnetv2 import EffnetV2_L
import joblib

# %%
transform = transforms.Compose([transforms.Resize((450, 600)),
                transforms.Pad((0, 0, 0, 150), fill = 0, padding_mode = 'constant'),
                transforms.Resize((512, 512)),
                transforms.Normalize(mean=0.1354949, std=0.18222201)])

# %%
dataset = Fetal_frame(root = '/data/kpusteln/fetal/fetal_extracted/', 
                    ann_path = '/data/kpusteln/Fetal-RL/data_preparation/data_biometry/ete_model/biometry_scaled_ps/biometry_test_scaled_size_subset.csv', 
                    transform = transform)

# %%
model = EffnetV2_L(in_channels = 1, out_features = 1)
path_to_model = '/data/kpusteln/Fetal-RL/swin-transformer/output/effnetv2_reg_l1_no_scaling_no_meta_drop04_new_lr_no_augm_no_sigm_avgpool/default/ckpt_epoch_47.pth'
checkpoint1 = torch.load(path_to_model, map_location='cpu')
msg1 = model.load_state_dict(checkpoint1['model'], strict=False)

# %%
data_loader_test = torch.utils.data.DataLoader(
    dataset, 
    batch_size=1,
    shuffle = False,
    drop_last = False)

# %%
model.eval()
# Out:
# EffnetV2_L(
#   (model): EfficientNet(
#     (features): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): Sequential(
#         (0): FusedMBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#         )
#         (1): FusedMBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
# ...

# %%
scaler = joblib.load('/data/kpusteln/Fetal-RL/data_preparation/data_biometry/ete_model/biometry_scaled_ps/normalizer_measure')

# %%
for idx, (images, Class, measure, ps, frames_n, measure_scaled, index, days_normalized, frame_loc, measure_normalized) in enumerate(data_loader_test):
        
    outputs = model(images)
    print(Class)
    print(measure)
    print(outputs)
    outputs = outputs.detach().cpu().numpy()
    ps = ps.detach().cpu().numpy()
    print(scaler.inverse_transform(outputs) * ps)
    print(measure_scaled)
    break
# Out:
# tensor([2])
# tensor([20.1900], dtype=torch.float64)
# tensor([[0.2395]], grad_fn=<AddmmBackward0>)
# [[5.75576601]]
# tensor([0.9684])

# %%
from PIL import Image
import torch
arr = images.permute(2, 0, 1).int().numpy()

# Create PIL image from array
im = Image.fromarray(arr)
 # open the image with the default viewer
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/my-envs/swin/lib/python3.7/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2952         try:
# -> 2953             mode, rawmode = _fromarray_typemap[typekey]
#    2954         except KeyError as e:
#
# KeyError: ((1, 1, 512), '<i4')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2012713/3901190178.py in <module>
#       4
#       5 # Create PIL image from array
# ----> 6 im = Image.fromarray(arr)
#       7  # open the image with the default viewer
#
# ~/my-envs/swin/lib/python3.7/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2953             mode, rawmode = _fromarray_typemap[typekey]
#    2954         except KeyError as e:
# ...

# %%
lista = [1,2,3,4]

# %%
lista[3:4]
# Out:
# [4]

# %%
import pandas as pd
import torch

# %%
results = []
result = torch.tensor([1])
#result = result.numpy()
results.append(result)

# %%
results.extend(result)

# %%
results = torch.stack(results)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1486443/628256171.py in <module>
# ----> 1 results = torch.stack(results)
#
# RuntimeError: stack expects each tensor to be equal size, but got [1] at entry 0 and [] at entry 1

# %%
results = results.numpy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1486443/314512348.py in <module>
# ----> 1 results = results.numpy()
#
# AttributeError: 'list' object has no attribute 'numpy'

# %%
results
# Out:
# [tensor([1]), tensor(1), tensor(1)]

# %%
data = pd.DataFrame(results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1486443/2641574647.py in <module>
# ----> 1 data = pd.DataFrame(results)
#
# ~/my-envs/swin/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     698                         columns,
#     699                         index,  # type: ignore[arg-type]
# --> 700                         dtype,
#     701                     )
#     702                     mgr = arrays_to_mgr(
#
# ~/my-envs/swin/lib/python3.7/site-packages/pandas/core/internals/construction.py in nested_data_to_arrays(data, columns, index, dtype)
#     481         columns = ensure_index(data[0]._fields)
#     482
# --> 483     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     484     columns = ensure_index(columns)
#     485
#
# ...

# %%
data
# Out:
#    0
# 0  1
# 1  1
# 2  1

# %%
data.to_csv('test.csv')

# %%
import pandas as pd
